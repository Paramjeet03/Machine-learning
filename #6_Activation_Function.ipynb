# %% [markdown]
# # Activation fuction :- These are use too  make more accurate the prediction . There are 2 type type of function use in classification regression.
#
# ## 1.) Sigmoid function (ovr):- it is best for only 2 class.
#
# ## 2.) Softmax function (multimonial):- it is best for more than 2 class.

# %%
import numpy as np
import pandas as pb
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pb.read_csv(r"A:\Ducat\PYTHON\phyton\data analytics\MACHINE LEARNING\DATASETS\IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.species.value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
feature=df.iloc[:,:4].values
print("dimension :- ",feature.ndim,"\n",feature) #2d array
# Out:
# dimension :-  2
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
# ...

# %%
target=df.species

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## ---> Model by Auto (Work only some time) :-

# %%
model1=LogisticRegression()
model1
# Out:
# LogisticRegression()

# %%
model1.fit(feature,target)
# Out:
# LogisticRegression()

# %%
model1.predict([[4.9,  3. , 1.4, 0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model1.predict_proba([[4.9,  3. , 1.4, 0.2]])
# Out:
# array([[9.71720996e-01, 2.82789740e-02, 2.98017352e-08]])

# %% [markdown]
# ## ---> Model by ovr (sgmoid) :-

# %%
model=LogisticRegression(multi_class='ovr')
model
# Out:
# LogisticRegression(multi_class='ovr')

# %%
model.fit(feature,target)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
model.predict([[4.9,  3. , 1.4, 0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model.predict_proba([[4.9,  3. , 1.4, 0.2]])
# Out:
# array([[7.82524451e-01, 2.17474228e-01, 1.32093735e-06]])

# %% [markdown]
# ## ---> Model by multinomial (softmax) :-

# %%
model2=LogisticRegression(multi_class='multinomial')
model2
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
model2.fit(feature,target)
# Out:
# LogisticRegression(multi_class='multinomial')

# %%
model2.predict([[4.9,  3. , 1.4, 0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
model2.predict_proba([[4.9,  3. , 1.4, 0.2]])
# Out:
# array([[9.71720996e-01, 2.82789740e-02, 2.98017352e-08]])
